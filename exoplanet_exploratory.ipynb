# %%
import pandas as pd
import seaborn as sns

# %%
raw_data = pd.read_csv('/Users/brianbeeler/Downloads/exo_data.csv')

# %%
raw_data.hist(column="sy_snum")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe24de90cd0>]],
#       dtype=object)

# %%
raw_data.hist(column='sy_pnum')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe24de90890>]],
#       dtype=object)

# %%
raw_data.plot.scatter(x='sy_snum', y='sy_pnum')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
data_columns = raw_data[['sy_snum', 'sy_pnum']]

filtered_suns     = data_columns["sy_snum"] != ""
filtered_planets  = data_columns["sy_pnum"] != ""

print(data_columns)

#sns.lmplot( hue='species', x=filtered_suns , y=filtered_planets, data=[filtered_suns, filtered_planets], fit_reg=False, x_jitter=0.1, y_jitter=0.1) 



#sns.lmplot(x=x_col, y=y_col, hue='species', data=[] )
# Out:
#        sy_snum  sy_pnum
# 0            2        1
# 1            2        1
# 2            1        1
# 3            1        1
# 4            1        1
# ...        ...      ...
# 26827        2        3
# 26828        2        3
# 26829        2        3
# 26830        1        1
# 26831        1        1
#
# [26832 rows x 2 columns]
